# %%
# Listas para armazenar os dados dos alunos
nomes_alunos = []  # Lista para armazenar os nomes dos alunos
numeros_alunos = []  # Lista para armazenar os números dos alunos

while True:
    print("Menu:")
    print("1. Adicionar aluno")
    print("2. Remover aluno")
    print("3. Consultar turma")
    print("4. Alterar nome do aluno")
    print("5. Sair")

    escolha = input("Escolha uma opção (1-5): ")

    if escolha == "1":
        # Adicionar aluno
        nome = input("Insira o nome do aluno: ")
        while True:
          #Aqui a verificação do nº inteiro tem que ser feita através do Ciclo
          #Em Loop "While True"
          try:
              numero = int(input("Insira o número do aluno: "))
              break  # Se a introdução for correta, sai do loop
          except ValueError:
                print("Erro: Insira um número inteiro válido.")

        # Verifica se o número já existe na lista de números
        if numero in numeros_alunos:
            print("Erro: Número de aluno já existente. Tente novamente.")
        else:
            nomes_alunos.append(nome)
            numeros_alunos.append(numero)
            print("Aluno adicionado com sucesso!")

    elif escolha == "2":
        # Remover aluno
        if not nomes_alunos:
            print("Não existem alunos na turma.")
        else:
            numero = int(input("Insira o número do aluno que deseja remover: "))
            if numero in numeros_alunos:
                # Encontra o índice do número na lista dos números dos alunos
                indice = numeros_alunos.index(numero)
                # Remove o nome e o número do aluno correspondente nas listas
                del nomes_alunos[indice]
                del numeros_alunos[indice]
                print("Aluno removido com sucesso!")

                # Atualiza os índices após a remoção
                for i in range(len(numeros_alunos)):
                    numeros_alunos[i] = i + 1
            else:
                print("Aluno não encontrado.")

    elif escolha == "3":
        # Consultar turma
        if not nomes_alunos:
            print("A turma está vazia.")
        else:
            print("Lista de Alunos:")
            for indice, (nome, numero) in enumerate(zip(nomes_alunos, numeros_alunos), start=1):
                # Imprime a lista de alunos enumerando-os
                print(f"Aluno {indice}: {nome} (Número: {numero})")

    elif escolha == "4":
        # Alterar nome do aluno
        if not nomes_alunos:
            print("A turma está vazia. Não há alunos para alterar.")
        else:
            numero = int(input("Insira o número do aluno cujo nome deseja alterar: "))
            if numero in numeros_alunos:
                # Encontra o índice do número na lista de números
                indice = numeros_alunos.index(numero)
                novo_nome = input("Insira o novo nome do aluno: ")
                # Atualiza o nome do aluno
                nomes_alunos[indice] = novo_nome
                print("Nome do aluno alterado com sucesso!")
            else:
                print("Aluno não encontrado.")

    elif escolha == "5":
        print("Programa Terminado!.")
        break

    else:
        print("Opção inválida. Escolha uma opção de 1 a 5.")
# Out:
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 1
# Insira o nome do aluno: Luís
# Insira o número do aluno: 1
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 1
# Insira o nome do aluno: João
# Insira o número do aluno: 2
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 2
# Insira o número do aluno que deseja remover: 1
# Aluno removido com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 3
# Lista de Alunos:
# Aluno 1: João (Número: 1)
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 1
# Insira o nome do aluno: Luís
# Insira o número do aluno: 1
# Erro: Número de aluno já existente. Tente novamente.
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 1
# Insira o nome do aluno: Luís
# Insira o número do aluno: 2
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 1
# Insira o nome do aluno: Ana
# Insira o número do aluno: 3
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 2
# Insira o número do aluno que deseja remover: 2
# Aluno removido com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 3
# Lista de Alunos:
# Aluno 1: João (Número: 1)
# Aluno 2: Ana (Número: 2)
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Sair
# Escolha uma opção (1-5): 5
# Programa Terminado!.
