# %% [markdown]
# <a href="https://colab.research.google.com/github/HelderFilipeVazRibeiro/Colab/blob/main/Soluc_T4_Com_Autom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Resolução duplicado

# %%
from IPython.display import clear_output

# Listas para armazenar os dados dos alunos
nomes_alunos = []  # Lista para armazenar os nomes dos alunos
numeros_alunos = []  # Lista para armazenar os números dos alunos
indice_aluno = 1  # Índice do próximo aluno a ser adicionado

while True:
    print("Menu:")
    print("1. Adicionar aluno")
    print("2. Remover aluno")
    print("3. Consultar turma")
    print("4. Alterar nome do aluno")
    print("5. Atualizar número do aluno")
    print("6. Limpar tela")
    print("7. Sair")

    escolha = input("Escolha uma opção (1-7): ")

    if escolha == "1":
        nome = input("Insira o nome do aluno: ")  # Adicionar aluno

        if nome in nomes_alunos: # Ve se já existe
            print("Erro: O nome do aluno que digitou já está na turma.")
            continue
        else: numero = indice_aluno  # incrementa
        indice_aluno += 1

        nomes_alunos.append(nome) # adiciona a array nome
        numeros_alunos.append(numero) # adiciona a array numero
        print("Aluno adicionado com sucesso!")

    elif escolha == "2":
        # Remover aluno
        if not nomes_alunos:
            print("Não existem alunos na turma.")
        else:
            print("Lista de Alunos:")
            for indice, (nome, numero) in enumerate(zip(nomes_alunos, numeros_alunos), start=1):
                # Imprime a lista de alunos enumerando-os
                print(f"Aluno {indice}: {nome} (Número: {numero})")

            numero = int(input("Insira o número do aluno que deseja remover: "))
            if numero in numeros_alunos:

                indice = numeros_alunos.index(numero) # índice

                del nomes_alunos[indice] # remove o nome na lista
                del numeros_alunos[indice] # remove número do aluno na lista
                print("Aluno removido com sucesso!")

                indice_aluno -= 1  # Atualiza o próximo índice

                print("\nLista de Alunos após a remoção:")
                for indice, (nome, numero) in enumerate(zip(nomes_alunos, numeros_alunos), start=1): # <----- actualiza a lista apos a remoção
                    print(f"Aluno {indice}: {nome} (Número: {numero})")

            else:
                print("Aluno não encontrado.")

    elif escolha == "3":
        # Consultar turma
        if not nomes_alunos:
            print("A turma está vazia.")
        else:
            print("Lista de Alunos:")
            for indice, (nome, numero) in enumerate(zip(nomes_alunos, numeros_alunos), start=1):
                # Imprime a lista de alunos enumerando-os
                print(f"Aluno {indice}: {nome} (Número: {numero})")

    elif escolha == "4":
        # Alterar nome do aluno
        if not nomes_alunos:
            print("A turma está vazia. Não há alunos para alterar.")
        else:
            numero = int(input("Insira o número do aluno cujo nome deseja alterar: "))
            if numero in numeros_alunos:
                # Encontra o índice do número na lista de números
                indice = numeros_alunos.index(numero)
                novo_nome = input("Insira o novo nome do aluno: ")
                # Atualiza o nome do aluno
                nomes_alunos[indice] = novo_nome
                print("Nome do aluno alterado com sucesso!")
            else:
                print("Aluno não encontrado.")

    elif escolha == "5":
        # Código para atualizar número do aluno
        if not nomes_alunos:
            print("A turma está vazia. Não há alunos para atualizar o número.")
        else:
            # Input para o utilizador introduzir o nº do Aluno a atualizar
            numero_antigo = int(input("Insira o número do aluno que deseja atualizar: "))
            if numero_antigo in numeros_alunos:
                # Encontra o índice do número na lista de números
                indice = numeros_alunos.index(numero_antigo)
                novo_numero = int(input("Insira o novo número do aluno: "))
                # Verifica se o novo número já existe
                if novo_numero in numeros_alunos:
                    print("Erro: Número de aluno já existente. Tente novamente.")
                else:
                    # Caso o nº não exista atualiza o nº de aluno
                    numeros_alunos[indice] = novo_numero
                    print("Número do aluno atualizado com sucesso!")
            else:
                print("Aluno não encontrado.")

    elif escolha == "6":
        # Código para limpar a tela (Google Colab)
        clear_output()

    elif escolha == "7":
        print("Programa Terminado! Obrigado!")
        break

    else:
        print("Opção inválida. Escolha uma opção de 1 a 7.")
# Out:
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Atualizar número do aluno
# 6. Limpar tela
# 7. Sair
# Escolha uma opção (1-7): 1
# Insira o nome do aluno: qwe
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Atualizar número do aluno
# 6. Limpar tela
# 7. Sair
# Escolha uma opção (1-7): 1
# Insira o nome do aluno: qwerty
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Atualizar número do aluno
# 6. Limpar tela
# 7. Sair
# Escolha uma opção (1-7): 1
# Insira o nome do aluno: abs
# Aluno adicionado com sucesso!
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Atualizar número do aluno
# 6. Limpar tela
# 7. Sair
# Escolha uma opção (1-7): 2
# Lista de Alunos:
# Aluno 1: qwe (Número: 1)
# Aluno 2: qwerty (Número: 2)
# Aluno 3: abs (Número: 3)
# Insira o número do aluno que deseja remover: 2
# Aluno removido com sucesso!
#
# Lista de Alunos após a remoção:
# Aluno 1: qwe (Número: 1)
# Aluno 2: abs (Número: 3)
# Menu:
# 1. Adicionar aluno
# 2. Remover aluno
# 3. Consultar turma
# 4. Alterar nome do aluno
# 5. Atualizar número do aluno
# 6. Limpar tela
# 7. Sair
# Escolha uma opção (1-7): 7
# Programa Terminado! Obrigado!
